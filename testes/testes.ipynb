# %%
import pandas as pd

# %%
df = pd.read_csv('results.csv')

# %%
df
# Out:
#     review_idx  cluster          aspect sentiment  mentions  confidence
# 0            0        0           price   neutral         1    0.785858
# 1            0        1            deli   neutral         1    0.478390
# 2            1        2          series  positive         1    0.708244
# 3            2        3           movie  positive         1    0.702357
# 4            3        4         writing   neutral         1    0.693513
# ..         ...      ...             ...       ...       ...         ...
# 61          45       43    ashley darby  negative         1    0.936164
# 62          47       38          dialog   neutral         1    0.509840
# 63          47       44          scenes   neutral         1    0.466797
# 64          48       45        features   neutral         1    0.528262
# 65          49       46  diane franklin  positive         1    0.853677
#
# [66 rows x 6 columns]
