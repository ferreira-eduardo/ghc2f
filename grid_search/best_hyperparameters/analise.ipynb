# %%
import pandas as pd

# %%
df_ae = pd.read_csv('All_Beauty_reviews_cf_autoencoder_stage3_confirmation.csv')
df_gated = pd.read_csv('All_Beauty_reviews_gated_hybrid_stage3_confirmation.csv')
df_ghc2f = pd.read_csv('All_Beauty_reviews_ghc2f_stage3_confirmation.csv')

# %%
print(df_ae)
# Out:
#    dropout     lr nl_type      layers  tied_weights  full_data_val_hit_rate
# 0      0.5  0.001    relu  mf_like_d2          True                0.254473
# 1      0.5  0.001    relu   narrow_d2          True                0.251491
# 2      0.5  0.001    relu   narrow_d2          True                0.250497

# %%
print(df_gated)
# Out:
#    dropout     lr nl_type      layers  tied_weights  full_data_val_hit_rate
# 0      0.5  0.001    relu     wide_d2          True                0.249503
# 1      0.5  0.001    relu  mf_like_d3         False                0.243539
# 2      0.2  0.001    relu      mid_d3         False                0.242545

# %%
print(df_ghc2f)
# Out:
#    dropout      lr nl_type      layers  tied_weights  full_data_val_hit_rate
# 0      0.5  0.0010    relu  mf_like_d2         False                0.253479
# 1      0.2  0.0001    relu      mid_d3          True                0.243539
# 2      0.5  0.0010    selu      mid_d2          True                0.230616
