# %%
import pandas as pd

# %%
df = pd.read_parquet('aspects_amazon.parquet')

# %%
df.shape
# Out:
# (212, 5)

# %%
df_aspects_sent = pd.read_csv('../results/amazon_aspects.csv')

# %%
df_aspects_sent
# Out:
#     review_idx  cluster                aspect sentiment  mentions  confidence  \
# 0            0        0                   kid  positive        12    0.933750
# 1            0        1            oval order  positive         1    0.985000
# 2            1        0                season  positive         1    0.988000
# 3            2        0                  disc  positive         1    0.986000
# 4            3        0         great writing  positive         1    0.953000
# 5            4        0              shipment  negative        14    0.655286
# 6            5        0                extent  positive        11    0.655545
# 7            6        0           face muscle  positive         2    0.970000
# 8            7        0               problem  positive         6    0.903667
# 9            8        0                 price  positive         1    0.915000
# 10          11        0              daughter  positive         3    0.954667
# ...

# %%
df_old = pd.read_csv('../../../aspect_cor-rating/results/amazon_aspects_agg.csv')
df_old.shape
# Out:
# (1378463, 9)

# %%
# df_old[df_old['review_idx'].isin(df_aspects_sent['review_idx'].unique())].to_csv('res_old.csv', index=False)

# %%
df_old = pd.read_parquet('aspects_amazon.parquet')

# %%
df_old
# Out:
#      review_idx                                             review  \
# 0             0  My kids are in love with this show so I had to...
# 1             0  My kids are in love with this show so I had to...
# 2             0  My kids are in love with this show so I had to...
# 3             0  My kids are in love with this show so I had to...
# 4             0  My kids are in love with this show so I had to...
# ..          ...                                                ...
# 208          48  I rented this movie and watched it with some c...
# 209          48  I rented this movie and watched it with some c...
# 210          48  I rented this movie and watched it with some c...
# 211          48  I rented this movie and watched it with some c...
# 212          49  Just finished watching this movie for the firs...
#
#                          aspect                      aspect_raw  cluster
# 0                          love                            love        6
# ...

# %%
df_aspects = pd.read_csv('../results/amazon_aspects.csv')

# %%
df_aspects
# Out:
#      review_idx  cluster                      aspect sentiment  mentions  \
# 0             0        1                        love  positive         1
# 1             0        2                  collection  positive         1
# 2             0        3                        junk  positive         1
# 3             0        6                        gift  positive         1
# 4             0        7  complete series collection  positive         1
# ..          ...      ...                         ...       ...       ...
# 208          48      205                    football   neutral         1
# 209          48      206                        life   neutral         1
# 210          48      207             special feature  positive         1
# 211          48      208                      friend   neutral         1
# 212          49      209                  first time  positive         1
#
#      confidence  prob_pos  prob_neu  prob_neg
# ...

# %%
df = pd.read_parquet('../../../dataset/amazon.parquet')
df = df.sample(n=min(50, df.shape[0]), random_state=42).reset_index(drop=True)

# %% [markdown]
# df['review']

# %%
df['review']
# Out:
# 0     My kids are in love with this show so I had to...
# 1     Amazon got it 100% correct! A great series. Lo...
# 2          Great movie, disc was delivered as expected.
# 3     Another very good Atom Agoyan film with great ...
# 4     I'm not so happy now. I received the shipment ...
# 5     Didn;t like the movie at first, but after view...
# 6     Your face muscles will ache from the many smil...
# 7     Despite some problems (Martin Sheen as Lee mak...
# 8     It was worth the price just to hear Adam West ...
# 9                                      Excellent series
# 10                              A good story well done.
# 11    My daughter loves Daniel Tiger and has learned...
# 12                                      One of the best
# 13    Red Oaks Season 1 was so good that it was inev...
# 14    I ordered a "new" DVD set. It was missing Disc...
# 15    These are the guys that do all the Vines. I lo...
# 16    was new and wrapped some scruff marks but shou...
# ...

# %%
DVD had deep scratches in it. Was described as new. As soon as I loaded DVD it would not play I tried cleaning DVD reloaded an it skipped an paused at very beginning NEVER moving from the scene! Kids were crying the thought they were going to watch an old classic movie!
This is an awesome movie. This movie will make you laugh and maybe cry! It shows the journey of a girl moving from one city to another and how her body and emotions play a roll. My entire family loves it. We watch it all the time together as a family. I love that it has the digital copy too. We put it on my daughters Ipad for traveling in the car on long family trips!
Great Danish film. This movie is hilarious and action packed. If you like Lock Stock or Snatch; You'll like this.
"First movie was far better. This one was kind of boring. Don't expect to be impressed with this movie, but its OK."
Great movie. Very thought provoking
I used the DVD for a Bible study group. It came right on time and worked great at the study.
Love this movie
"I won't review the movie itself. It's a classic, and probably the best of the bunch. The Blu-ray transfer is superb. It looks and sounds like it was just made, which is the main reason to buy a blu ray of an old movie, right? You can watch this and Prometheus side by side, and wonder how 30 years could have passed between them."
A must have for Johnny Maestro fans! Fabulous collection! All my favs. The voice of a very classy angel.
Please get Ashley Darby and her horrible husband off this show. They both are a disrespect to women and the #metoo movement.
"I watched this for the second time tonight, the first being in 2008 while I was living in Paris. Unlike many films, it doesn't seem dated. If anything, I think I appreciated it more this time around."
"In some scenes the acting was stiff. Not due to cultural behavior but in the acting i.e. the 'gang' in East Berlin, the dialogs in the Russian embassy and the family interaction between Tom Hanks and his 'wife'."
"I rented this movie and watched it with some close friends yesterday and just had to watch it a second time today. While the movie is about a football team, it really isn't as much a movie about football as it is about life, our goals, our hopes and dreams. It helps one to reflect upon what is and what is not truly important in life. Whether you rent this or buy this, it is worth watching and be sure to watch the special features. I'm planning to buy this movie and probably an extra copy or two for friends and family."
Just finished watching this movie for the first time in years. still love it. Diane Franklin is beautiful. This could be the best 80's movie! Its definitely the most underrated 80's movie.

# %%
pure_mode = pd.read_csv('../../../dataset/amazon_absa_test.csv')

# %%
pure_mode
# Out:
#                                                  text  \
# 0   My kids are in love with this show so I had to...
# 1   Amazon got it 100% correct! A great series. Lo...
# 2        Great movie, disc was delivered as expected.
# 3   Another very good Atom Agoyan film with great ...
# 4   I'm not so happy now. I received the shipment ...
# 5   Didn; t like the movie at first, but after vie...
# 6   Your face muscles will ache from the many smil...
# 7   Despite some problems (Martin Sheen as Lee mak...
# 8   It was worth the price just to hear Adam West ...
# 9                                    Excellent series
# 10                            A good story well done.
# 11  My daughter loves Daniel Tiger and has learned...
# 12                                    One of the best
# 13  Red Oaks Season 1 was so good that it was inev...
# 14  I ordered a "new" DVD set. It was missing Disc...
# 15  These are the guys that do all the Vines. I lo...
# ...

# %%
v3 = pd.read_csv('../results/amazon_absa_v4_aspects.csv')

# %%
v3
# Out:
#      review_idx  cluster          aspect sentiment  mentions  confidence  \
# 0             0        0      collection   neutral         1    0.905500
# 1             0        1             dvd   neutral         1    0.994639
# 2             0        2            gift  positive         1    0.810895
# 3             0        3           price  positive         1    0.907941
# 4             0        4            deli  positive         1    0.993622
# ..          ...      ...             ...       ...       ...         ...
# 122          48       94            rent   neutral         1    0.909154
# 123          48       95         special  positive         1    0.960818
# 124          48       96        features  positive         1    0.980559
# 125          49        9           movie  positive         3    0.941484
# 126          49       97  diane franklin  positive         1    0.917315
#
#      pct_classifier_fallback  prob_positive  prob_negative  prob_neutral
# ...
